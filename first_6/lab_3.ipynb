# %% [markdown]
# **1.Перечислите возможные гиперпараметры модели линейной регрессии.**

# %% [markdown]
# Скорость обучения, коэффициент регуляризации (L1/L2), максимальное количество итераций, метод оптимизации.

# %% [markdown]
# **2. Может ли коэффициент детерминации быть отрицательным
# числом?**

# %% [markdown]
# Да, если модель предсказывает хуже, чем среднее значение целевой переменной.

# %% [markdown]
# **3. Оцените MSE для следующих данных: реальные значения y {1, 2, 3, 4}, предсказания модели y {2, 1, 4, 6}.**

# %% [markdown]
# MSE:(2−1)^2+(1−2)^2+(4−3)^2+(6−4)^2=1+1+1+4=7, MSE= 7/4 = 1.75

# %% [markdown]
# **4. Предположим, что у вас есть вектор весов w {10, 5, 6}. Вы посчитали градиент функции потерь, который равен {20, −10, 40}.
# Посчитайте обновленный вектор весов при условии, что скорость обучения составляет 0.1.**

# %% [markdown]
# w new = w − learning rate × gradient = {10,5,6} − 0.1 × {20,−10,40} = {8,6,2}.

# %% [markdown]
# **5. Перечислите данные, которые вам необходимы для расчета градиента функции потерь.**

# %% [markdown]
# Необходимые данные для расчета градиента: текущие веса, данные X, реальные значения Y, функция потерь.

# %% [markdown]
# **6. Вы выполнили обучение линейной модели дважды: с регуляризацией и без. У вас есть два вектора весов модели w1 {14.37, 22.80, 32.20} и w2 {0.69, 2.02, 4.20}, но вы не помните, какой вектор весов какой модели соответствует. Как вы считаете, который из при- веденных весов соответствует случаю регуляризации?**

# %% [markdown]
# Вес с регуляризацией: 𝑤2 = { 0.69 , 2.02 , 4.20 }, так как значения меньше из-за штрафа за большие веса.

# %% [markdown]
# **7. Вы получили веса модели w {3, −2, 2}. В модели не используется смещение. Оцените предсказание модели для следующих значений параметров x {1, 3, 1}.**

# %% [markdown]
# y=3⋅1−2⋅3+2⋅1=3−6+2=−1.

# %% [markdown]
# **8. Оцените коэффициент детерминации для следующих данных: реальные значения y {1, 2, 3, 4}, предсказания модели y {2, 1, 4, 6}.**

# %% [markdown]
# R^2=1−SStot/SSres, где SSres = (2−1)^2+(1−2)^2+(4−3)^2+(6−4)^2=7, SStot = (1−2.5)^2+(2−2.5)^2+(3−2.5)^2+(4−2.5)^2 = 5. 𝑅^2=1−7/5 = −0.4.
