# %% [markdown]
# **1. Допустим, тест на некое заболевание R дал положительный ответ, хотя на самом деле у испытуемого нет этого заболевания. Какую ошибку допустил тест?**

# %% [markdown]
# Ошибка: Ложноположительная ошибка (False Positive, FP).

# %% [markdown]
# **2. Пусть в матрице ошибок TP = 5, TN = 90, FP = 10, FN = 5. Оцените метрики классификации для такой матрицы ошибок.**

# %% [markdown]
# Точность (Accuracy) = (5 + 90) / (5 + 90 + 10 + 5) = 0.864
#
# Точность (Precision) = 5 / (5 + 10) = 0.333
#
# Чувствительность (Recall, Sensitivity) = 5 / (5 + 5) = 0.5
#
# Специфичность (Specificity) = 90 / (90 + 10) = 0.9
#
# F1-мера = 2 * 0.333 * 0.5 / (0.333 + 0.5) = 0.4

# %% [markdown]
# **3. Допустим, есть два классификатора: первый классификатор имеет долю правильных ответов 95 %, чувствительность 99 %, специфичность 50 %; второй классификатор имеет долю правильных ответов 87 %, чувствительность 84 %, специфичность 94 %. Что вы можете сказать о данных, используемых для классификации? Какой из этих классификаторов надежнее (при условии, что важно определение обоих классов)?**

# %% [markdown]
# Первый классификатор подходит для задачи с преобладанием одного класса (асимметрия данных), второй — для сбалансированных данных. Второй классификатор надежнее для определения обоих классов благодаря высокой специфичности.

# %% [markdown]
# **4. Перечислите возможные гиперпараметры модели логистической регрессии**

# %% [markdown]
# Коэффициент регуляризации, тип регуляризации (L1/L2), метод оптимизации, скорость обучения, порог классификации.

# %% [markdown]
# **5. Для набора данных Cars проанализируйте веса моделей при использовании только числовых признаков. Назовите параметр, который в наибольшей степени связан с целевой переменной.**

# %% [markdown]
# Признак Year (год выпуска) имеет наибольшую корреляцию с целевой переменной Price(euro), с коэффициентом корреляции 0.099. Это указывает на слабую положительную связь между годом выпуска автомобиля и его ценой.

# %% [markdown]
# **6. Оцените значение функции сигмоиды q(z) при z = 0.25**

# %% [markdown]
# σ(z) = 1 / 1+e^−z, σ(0.25) = 1/ 1+e^−0.25 1 ≈ 0.562.

# %% [markdown]
# **7. Оцените значение производной функции сигмоиды σ'(z) для z = –3.**

# %% [markdown]
# σ′(z) = σ(z)(1−σ(z)), σ(−3)≈0.047, σ′(−3) ≈ 0.047⋅(1−0.047) ≈ 0.045.

# %% [markdown]
# **8. Назовите, к какому классу следует отнести результат логистической модели для z = 0.1, если порог равен 0.6.**

# %% [markdown]
# Класс: 𝜎 ( 0.1 ) ≈ 0.525, меньше порога 0.6, поэтому класс 0.

# %% [markdown]
# **9. Оцените значение функции потерь (бинарной кросс-энтропии) для предсказания модели y = 0.1 и целевой переменной y = 1**

# %% [markdown]
# L = −[y⋅log(y′)+(1−y)⋅log(1−y′)], L = −[1⋅log(0.1)+0⋅log(0.9)] = −log(0.1) ≈ 2.302.
